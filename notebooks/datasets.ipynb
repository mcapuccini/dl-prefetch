# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Bodytrack

# %%
bodytrack = np.load('/traces/bodytrack/autocorr.npy')

# %%
plt.plot(bodytrack[:,0], bodytrack[:,1])
