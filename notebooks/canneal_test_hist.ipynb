# %%
# Imports
import numpy as np
from matplotlib import pyplot as plt

# %%
# Load data
trace = np.fromfile('../data/canneal_test/roitrace.bin', dtype=np.uint)
trace
# Out:
# array([140736143373704, 140736143373704, 140736143373696, ...,
#        140736143373704, 140736143373704,  93906089696944], dtype=uint64)

# %%
# Compute deltas
deltas = np.array(trace[1:] - trace[:-1], dtype=np.int_)
deltas
# Out:
# array([              0,              -8,              -8, ...,
#                      8,               0, -46830053676760])

# %%
# Plot train set classes histogram
# %matplotlib inline
hist = plt.hist(deltas, bins=50)
